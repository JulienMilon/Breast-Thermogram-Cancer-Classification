-09.14.jpg', 'T0055.1.5.S.2012-11-19.00.jpg', 'T0105.1.3.D.2012-11-30.00.jpg', 'T0137.1.1.D.2013-01-18.05.jpg', 'T0031.1.5.D.2012-10-19.00.jpg', 'T0135.1.5.S.2013-01-25.00.jpg', 'T0067.1.1.D.2012-11-21.00.jpg', 'T0116.1.1.D.2013-01-16.12.jpg', 'T0141.1.1.D.2013-01-25.19.jpg', 'T0172.1.1.D.2013-03-18.07.jpg', 'T0153.1.1.D.2013-02-01.11.jpg', 'T0197.1.1.D.2013-10-07.13.jpg', 'T0172.1.1.D.2013-03-18.06.jpg', 'T0019.1.3.D.2012-10-31.00.jpg', 'T0183.1.1.D.2013-05-24.11.jpg', 'T0115.1.1.D.2013-01-16.08.jpg', 'T0236.1.1.D.2014-05-21.19.jpg', 'T0145.1.1.D.2013-01-29.15.jpg', 'T0037.1.1.D.2012-10-29.10.jpg', 'T0145.1.1.D.2013-01-29.07.jpg', 'T0193.1.1.D.2013-10-02.14.jpg', 'T0121.1.1.D.2013-01-21.07.jpg', 'T0068.1.2.S.2012-11-21.00.jpg', 'T0272 ...

# %%
image = cv2.imread(path + "Healthy/T0001.1.1.D.2012-10-08.00.jpg", 0)

# %%
plt.imshow(image)
plt.xticks([]), plt.yticks([])  # Hides the graph ticks and x / y axis
plt.show()

# %%
equ = cv2.equalizeHist(image)

# %%
heatmap_turbo = cv2.applyColorMap(image, cv2.COLORMAP_TURBO)
heatmap_equ = cv2.applyColorMap(equ, cv2.COLORMAP_TURBO)


heatmap2_turbo = cv2.cvtColor(heatmap_turbo, cv2.COLOR_BGR2RGB)
heatmap2_equ = cv2.cvtColor(heatmap_equ, cv2.COLOR_BGR2RGB)

# %%
# create figure 
fig = plt.figure(figsize=(10, 7)) 
  
# setting values to rows and column variables 
rows = 2
columns = 2

# Adds a subplot at the 1st position 
fig.add_subplot(rows, columns, 1) 

# showing image 
plt.imshow(image) 
plt.axis('off') 
plt.title("No Processing") 
  
# Adds a subplot at the 2nd position 
fig.add_subplot(rows, columns, 2) 
  
# showing image 
plt.imshow(equ) 
plt.axis('off') 
plt.title("Histograms Equalization") 
  
# Adds a subplot at the 3rd position 
fig.add_subplot(rows, columns, 3) 
  
# showing image 
plt.imshow(heatmap2_turbo) 
plt.axis('off') 
plt.title("Heatmap No processing") 
  
# Adds a subplot at the 4th position 
fig.add_subplot(rows, columns, 4) 
  
# showing image 
plt.imshow(heatmap2_equ) 
plt.axis('off') 
plt.title("Heatmap Histograms Equalization")
# Out:
# Text(0.5, 1.0, 'Heatmap Histograms Equalization')
